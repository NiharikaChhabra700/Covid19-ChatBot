# %%
import pandas as pd
import numpy as np
import nltk
import sklearn

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("output1.csv" ,header =None)
df = df.dropna()
df.head()
# Out:
#                                                    0  \
# 0                                               Text
# 2  RT @ProSyn: Reaching enough people to stop #CO...
# 4  I have tested positive for #COVID19 and here’s...
# 6  62/ The horizontal red line represents median ...
# 8  #Remedisivir DOES NOT save lives, it is not an...
#
#                                                    1
# 0                                  Boolean Questions
# 2  ['Is there such a thing as covid19?', 'Is ther...
# 4  ['Is there a vaccine for covid19?', 'Is there ...
# 6  ['Is the horizontal red line the median neutra...
# 8  ['Is remedisivir a life saving drug?', 'Is rem...

# %%
df.columns=["text", "questions"]

# %%
df
# Out:
#                                                    text  \
# 0                                                  Text
# 2     RT @ProSyn: Reaching enough people to stop #CO...
# 4     I have tested positive for #COVID19 and here’s...
# 6     62/ The horizontal red line represents median ...
# 8     #Remedisivir DOES NOT save lives, it is not an...
# ...                                                 ...
# 1888  #COVID19 ICU in #Ontario 🏥    ICU total: 151  ...
# 1890  RT @AlexMMTri: Very excited to have @KPNorthwe...
# 1892  No region, country or individual should face m...
# 1894  Did any one here get vaccinated with COVAXIN a...
# 1896  Hospitalized guy refuses to get vaccinated—ask...
#
#                                               questions
# 0                                     Boolean Questions
# 2     ['Is there such a thing as covid19?', 'Is ther...
# 4     ['Is there a vaccine for covid19?', 'Is there ...
# 6     ['Is the horizontal red line the median neutra...
# ...

# %%
df = df.drop(index=0)
df
# Out:
#                                                    text  \
# 2     RT @ProSyn: Reaching enough people to stop #CO...
# 4     I have tested positive for #COVID19 and here’s...
# 6     62/ The horizontal red line represents median ...
# 8     #Remedisivir DOES NOT save lives, it is not an...
# 10    RT @Hoybraten: EU at it’s worst: Most COVAX Va...
# ...                                                 ...
# 1888  #COVID19 ICU in #Ontario 🏥    ICU total: 151  ...
# 1890  RT @AlexMMTri: Very excited to have @KPNorthwe...
# 1892  No region, country or individual should face m...
# 1894  Did any one here get vaccinated with COVAXIN a...
# 1896  Hospitalized guy refuses to get vaccinated—ask...
#
#                                               questions
# 2     ['Is there such a thing as covid19?', 'Is ther...
# 4     ['Is there a vaccine for covid19?', 'Is there ...
# 6     ['Is the horizontal red line the median neutra...
# 8     ['Is remedisivir a life saving drug?', 'Is rem...
# ...

# %%
list = []
s=[]
xyz=[]
for ind in df.index: 
    list=df['questions'][ind]
    s=list.split(',')
    k=len(s)
    s[0]=s[0][1:]
    s[-1]=s[-1][:k-1]
    
    n=len(s)
    for i in range (n):
        s[i]= s[i].replace("'", "")
        xyz.append(s[i])


while(" " in xyz) :
    xyz.remove(" ")
print(xyz)
type(xyz[0])
# Out:
# ['Is there such a thing as covid19?', ' Is there such a thing as covid19?', 'Is there a vaccine for covid19?', ' Is there such a thing as covid19?', 'Is the horizontal red line the median neutralizing antibody titer?', ' Is the median neutralizing antibody titer true or false?', 'Is remedisivir a life saving drug?', ' Is remedisivir the only drug that saves lives?', 'Is there a green pass for covax vaccine?', ' Is the covax vaccine funded by the eu?', 'Do you have to get a t cell vaccine?', ' Is it possible to get t cell immunity?', 'Is there such a thing as dehydration?', ' Is there a difference between water and electrolytes?', 'Is there a pandemic in korea?', ' Is korea part of the pandemic response?', 'Is vax it and mask it the same thing?', ' Is there a difference between delta and delta strain?', 'Is the delta vaccine true or false?', ' Is the pfizer delta vaccine true or false?', 'Do you have to go to the doctor for treatment?', ' Is it normal to have a headache?', 'Is there s
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import euclidean_distances

# %%
vectorizer = CountVectorizer()
features = vectorizer.fit_transform(xyz).todense()

# %%
print( vectorizer.vocabulary_ )
# Out:
# {'is': 524, 'there': 986, 'such': 945, 'thing': 988, 'as': 97, 'covid19': 248, 'vaccine': 1051, 'for': 379, 'the': 982, 'horizontal': 459, 'red': 838, 'line': 580, 'median': 621, 'neutralizing': 688, 'antibody': 82, 'titer': 1003, 'true': 1021, 'or': 727, 'false': 354, 'remedisivir': 845, 'life': 574, 'saving': 875, 'drug': 314, 'only': 722, 'that': 981, 'saves': 874, 'lives': 585, 'green': 423, 'pass': 758, 'covax': 243, 'funded': 392, 'by': 158, 'eu': 337, 'do': 298, 'you': 1128, 'have': 433, 'to': 1005, 'get': 405, 'cell': 183, 'it': 530, 'possible': 786, 'immunity': 483, 'dehydration': 272, 'difference': 290, 'between': 132, 'water': 1091, 'and': 75, 'electrolytes': 329, 'pandemic': 754, 'in': 496, 'korea': 555, 'part': 756, 'of': 711, 'response': 852, 'vax': 1064, 'mask': 611, 'same': 867, 'delta': 274, 'strain': 933, 'pfizer': 772, 'go': 410, 'doctor': 299, 'treatment': 1016, 'normal': 698, 'headache': 436, 'covid': 247, 'india': 501, 'fund': 391, 'hindu': 452, 'pampathkumar': 
# ...

# %%
for f in features:
    print( euclidean_distances(features[0], f) )
# Out:
# [[0.]]
# [[0.]]
# [[2.23606798]]
# [[0.]]
# [[4.]]
# [[3.60555128]]
# [[3.]]
# [[3.46410162]]
# [[3.]]
# [[3.74165739]]
# [[3.60555128]]
# [[3.31662479]]
# [[1.41421356]]
# [[3.]]
# [[2.64575131]]
# [[3.31662479]]
# [[3.60555128]]
# [[3.46410162]]
# [[3.31662479]]
# [[3.46410162]]
# [[4.24264069]]
# [[3.16227766]]
# [[2.]]
# [[3.]]
# [[3.60555128]]
# [[3.46410162]]
# [[2.64575131]]
# [[1.41421356]]
# [[3.46410162]]
# [[3.87298335]]
# [[3.60555128]]
# [[3.60555128]]
# [[3.]]
# [[3.]]
# [[3.16227766]]
# [[2.64575131]]
# [[3.]]
# [[3.31662479]]
# [[1.73205081]]
# [[3.31662479]]
# [[1.73205081]]
# [[3.16227766]]
# [[3.]]
# [[4.24264069]]
# [[1.73205081]]
# [[4.]]
# [[2.64575131]]
# [[3.]]
# [[3.46410162]]
# [[3.60555128]]
# [[1.73205081]]
# [[3.16227766]]
# [[3.]]
# [[2.82842712]]
# [[3.]]
# [[2.82842712]]
# [[2.64575131]]
# [[3.31662479]]
# [[1.73205081]]
# [[3.31662479]]
# [[4.12310563]]
# [[3.]]
# [[2.23606798]]
# [[3.74165739]]
# [[3.31662479]]
# [[3.16227766]]
# [[3.]]
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Is delta variant the fastest covid variant?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                           strings
# 549    0.168184               Is delta the fastest covid variant?
# 550    0.255958   Is delta the fastest and fittest covid variant?
# 1813   0.334817           Is the delta variant the same as covid?
# 985    0.357751                 Is deltaariant the same as covid?
# 428    0.367097        Is delta variant the same as delta strain?
# ...         ...                                               ...
# 120    1.114056           Does sputnikvaccine neutralize b.1.351?
# 1016   1.131087                     Can a person die from b1.1.7?
# 1642   1.359297                                                 "
# 256    1.359297                                                 "
# 1035   1.359297                                                 "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Does sars cov-2 affect the innate immune system?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 361    0.291431   Is sars cov-2 good for the innate immune system?
# 362    0.387475   Does sars cov-2 suppress the innate immune sy...
# 1554   0.531027  Is your immune system still active after an in...
# 1062   0.534963  Is there such a thing as an anti-vaccine movem...
# 735    0.537478            Is there a vaccine for t-cell immunity?
# ...         ...                                                ...
# 894    1.135070                Is there a vaccine in quatuquerque?
# 120    1.148522            Does sputnikvaccine neutralize b.1.351?
# 1642   1.360098                                                  "
# 1035   1.360098                                                  "
# 256    1.360098                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'What is the correlation between vaccination rate and case count?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 452    0.174321   Is there a correlation between vaccination ra...
# 451    0.196457  Is there a correlation between vaccination rat...
# 726    0.379645   Is there a difference between intubation and ...
# 1648   0.387502   Is there a correlation between vaccines and i...
# 248    0.403393  Is there such thing as low platelet after vacc...
# ...         ...                                                ...
# 1016   1.096748                      Can a person die from b1.1.7?
# 483    1.100603       Is it possible to have a b.1.617.2 mutation?
# 1642   1.358248                                                  "
# 1035   1.358248                                                  "
# 256    1.358248                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Should we still wear a mask?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 884    0.494744                  Is it illegal to not wear a mask?
# 883    0.499456              Is it legal to wear a mask in the us?
# 1595   0.507009             Is there a public rally with no masks?
# 1168   0.517361                  Is it safe to wear a double mask?
# 976    0.553484   Is there such thing as a lack of women in the...
# ...         ...                                                ...
# 529    1.218985      Is b.1.617.2 a variant of concern in ontario?
# 1138   1.218985      Is b.1.617.2 a variant of concern in ontario?
# 1035   1.357371                                                  "
# 1642   1.357371                                                  "
# 256    1.357371                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Is covid vaccine safe and how much effective is it?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                        strings
# 206    0.318238       Is the covid vaccine safe and effective?
# 1423   0.329063       Is the sinovac vaccine safe in the wild?
# 306    0.374582   Is the hcfi vaccine a true or false vaccine?
# 166    0.377010   Is the covid vaccine effective if not given?
# 548    0.380089        Is there a vaccine for covid in the us?
# ...         ...                                            ...
# 120    1.116351        Does sputnikvaccine neutralize b.1.351?
# 483    1.118341   Is it possible to have a b.1.617.2 mutation?
# 256    1.346133                                              "
# 1035   1.346133                                              "
# 1642   1.346133                                              "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Do you need to be vaccinated against covid19?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                           strings
# 455    0.192617     Do you have to be vaccinated against covid19?
# 587    0.373087       Do you have to be vaccinated against covid?
# 502    0.375534   Do you have to get vaccinated against covid-19?
# 63     0.377011       Do you have to be vaccinated against covid?
# 1367   0.377011       Do you have to be vaccinated against covid?
# ...         ...                                               ...
# 1424   1.098895                   Is 3 weeks the same as 8 weeks?
# 894    1.130197               Is there a vaccine in quatuquerque?
# 1035   1.354704                                                 "
# 1642   1.354704                                                 "
# 256    1.354704                                                 "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Does covid cause illness in kids?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 903    0.406630                         Is covid harmless in kids?
# 1543   0.503256   Is science and solidarity the key to a succes...
# 1706   0.537804                 Does covishield cause blood clots?
# 371    0.546434  Is public health and social measures effective...
# 904    0.558197         Is it true that covid is harmless in kids?
# ...         ...                                                ...
# 1138   1.152418      Is b.1.617.2 a variant of concern in ontario?
# 529    1.152418      Is b.1.617.2 a variant of concern in ontario?
# 1642   1.359937                                                  "
# 256    1.359937                                                  "
# 1035   1.359937                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Is it normal to have a fever or headache?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                       strings
# 21     0.271822              Is it normal to have a headache?
# 1808   0.320330         Is there a vaccine for delta vietnam?
# 113    0.324283         Is the moderna vaccine true or false?
# 694    0.342311            Is there a new normal after covid?
# 1249   0.364331        Is it true or false to have a vaccine?
# ...         ...                                           ...
# 483    1.097289  Is it possible to have a b.1.617.2 mutation?
# 120    1.141274       Does sputnikvaccine neutralize b.1.351?
# 256    1.339330                                             "
# 1035   1.339330                                             "
# 1642   1.339330                                             "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Is there any side effect of moderna vaccine?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 112    0.187633         Is there a side effect of moderna vaccine?
# 1405   0.350297            Is there a difference in vaccine cases?
# 724    0.356000   Is there a difference between true and false ...
# 1873   0.358364  Is there a vaccine verification system in france?
# 723    0.366822  Is there a difference between true and false e...
# ...         ...                                                ...
# 120    1.116118            Does sputnikvaccine neutralize b.1.351?
# 483    1.145101       Is it possible to have a b.1.617.2 mutation?
# 1035   1.352802                                                  "
# 256    1.352802                                                  "
# 1642   1.352802                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Are toci and remdesivir the same?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                       strings
# 33     0.312433      Is remeddesivir and toci the same thing?
# 32     0.333953        Is toci and remdesivir the same thing?
# 1744   0.393541       Is there a pandemic in the middle east?
# 301    0.399520       Is there a reason for vaccine mandates?
# 113    0.406811         Is the moderna vaccine true or false?
# ...         ...                                           ...
# 483    1.120132  Is it possible to have a b.1.617.2 mutation?
# 120    1.125804       Does sputnikvaccine neutralize b.1.351?
# 1642   1.356974                                             "
# 256    1.356974                                             "
# 1035   1.356974                                             "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Are oxford vaccine and astra zeneca same?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                           strings
# 888    0.340024   Is the oxford vaccine the same as astra zeneca?
# 1312   0.407898         Is there a vaccine for covax in tanzania?
# 1573   0.411258          Are moderna and pfizer the same vaccine?
# 887    0.441277    Is the oxford and astra zeneca the same thing?
# 1572   0.457218           Is moderna and pfizer the same vaccine?
# ...         ...                                               ...
# 373    1.131607                     Is it possible to be on b117?
# 483    1.175792      Is it possible to have a b.1.617.2 mutation?
# 1642   1.361821                                                 "
# 1035   1.361821                                                 "
# 256    1.361821                                                 "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Are cdc guidlines on masking changed? '

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 1833   0.235471          Is the cdc guidance on masking unchanged?
# 1834   0.296259   Does the cdc have guidance on masking unchanged?
# 859    0.441914                        Can smoking lead to cancer?
# 1553   0.454543        Do all nursing home workers get vaccinated?
# 1552   0.487163            Do nursing home workers get vaccinated?
# ...         ...                                                ...
# 894    1.133100                Is there a vaccine in quatuquerque?
# 483    1.175685       Is it possible to have a b.1.617.2 mutation?
# 1035   1.355793                                                  "
# 1642   1.355793                                                  "
# 256    1.355793                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Are delta and gamma variant different?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 1823   0.366278  Is there a difference between delta and gamma ...
# 1824   0.387258   Is there a difference between delta and gamma...
# 1752   0.469999    Do beta and gamma variants have the same titer?
# 1386   0.475428             Is there a vaccine for lambda variant?
# 134    0.482515           Is delta and deltaariant the same thing?
# ...         ...                                                ...
# 483    1.169840       Is it possible to have a b.1.617.2 mutation?
# 373    1.171050                      Is it possible to be on b117?
# 1642   1.367532                                                  "
# 256    1.367532                                                  "
# 1035   1.367532                                                  "
#
# [1897 rows x 2 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer="char")
string = 'Can you take the covid19 vaccine if you have high blood pressure?'

sparse_matrix = tfidf_vectorizer.fit_transform([string]+xyz)
euclidean= euclidean_distances(sparse_matrix[0,:],sparse_matrix[1:,:])
pd.DataFrame({'euclidean':euclidean[0],'strings':xyz}).sort_values('euclidean',ascending=True)
# Out:
#       euclidean                                            strings
# 1350   0.184457  Can you take the covid19 vaccine for high bloo...
# 572    0.427934                  Is there a covid 19 in la county?
# 455    0.435735      Do you have to be vaccinated against covid19?
# 542    0.436032      Do you have to be vaccinated against the flu?
# 919    0.436931        Is the movie covid19 based on a true story?
# ...         ...                                                ...
# 717    1.068648  Is there a difference between 300 and 300 anti...
# 894    1.079542                Is there a vaccine in quatuquerque?
# 1642   1.345050                                                  "
# 1035   1.345050                                                  "
# 256    1.345050                                                  "
#
# [1897 rows x 2 columns]
