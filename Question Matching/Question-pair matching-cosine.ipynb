# %%
import pandas as pd
import numpy as np
import nltk
import sklearn

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("final_questions.csv" ,header =None)
df = df.dropna()
df.head()
# Out:
#                                                    0  \
# 0                                               Text
# 2  RT @ProSyn: Reaching enough people to stop #CO...
# 4  I have tested positive for #COVID19 and here’s...
# 6  62/ The horizontal red line represents median ...
# 8  #Remedisivir DOES NOT save lives, it is not an...
#
#                                                    1
# 0                                  Boolean Questions
# 2  ['Is there such a thing as covid19?', 'Is ther...
# 4  ['Is there a vaccine for covid19?', 'Is there ...
# 6  ['Is the horizontal red line the median neutra...
# 8  ['Is remedisivir a life saving drug?', 'Is rem...

# %%
df.columns=["text", "questions"]

# %%
df
# Out:
#                                                    text  \
# 0                                                  Text
# 2     RT @ProSyn: Reaching enough people to stop #CO...
# 4     I have tested positive for #COVID19 and here’s...
# 6     62/ The horizontal red line represents median ...
# 8     #Remedisivir DOES NOT save lives, it is not an...
# ...                                                 ...
# 1888  #COVID19 ICU in #Ontario 🏥    ICU total: 151  ...
# 1890  RT @AlexMMTri: Very excited to have @KPNorthwe...
# 1892  No region, country or individual should face m...
# 1894  Did any one here get vaccinated with COVAXIN a...
# 1896  Hospitalized guy refuses to get vaccinated—ask...
#
#                                               questions
# 0                                     Boolean Questions
# 2     ['Is there such a thing as covid19?', 'Is ther...
# 4     ['Is there a vaccine for covid19?', 'Is there ...
# 6     ['Is the horizontal red line the median neutra...
# ...

# %%
df = df.drop(index=0)
df
# Out:
#                                                    text  \
# 2     RT @ProSyn: Reaching enough people to stop #CO...
# 4     I have tested positive for #COVID19 and here’s...
# 6     62/ The horizontal red line represents median ...
# 8     #Remedisivir DOES NOT save lives, it is not an...
# 10    RT @Hoybraten: EU at it’s worst: Most COVAX Va...
# ...                                                 ...
# 1888  #COVID19 ICU in #Ontario 🏥    ICU total: 151  ...
# 1890  RT @AlexMMTri: Very excited to have @KPNorthwe...
# 1892  No region, country or individual should face m...
# 1894  Did any one here get vaccinated with COVAXIN a...
# 1896  Hospitalized guy refuses to get vaccinated—ask...
#
#                                               questions
# 2     ['Is there such a thing as covid19?', 'Is ther...
# 4     ['Is there a vaccine for covid19?', 'Is there ...
# 6     ['Is the horizontal red line the median neutra...
# 8     ['Is remedisivir a life saving drug?', 'Is rem...
# ...

# %%
list = []
s=[]
questions=[]
for ind in df.index: 
    list=df['questions'][ind]
    s=list.split(',')
    k=len(s)
    s[0]=s[0][1:]
    s[-1]=s[-1][:k-1]
    
    n=len(s)
    for i in range (n):
        s[i]= s[i].replace("'", "")
        questions.append(s[i])


while(" " in questions) :
    questions.remove(" ")
print(questions)
type(questions[0])
# Out:
# ['Is there such a thing as covid19?', ' Is there such a thing as covid19?', 'Is there a vaccine for covid19?', ' Is there such a thing as covid19?', 'Is the horizontal red line the median neutralizing antibody titer?', ' Is the median neutralizing antibody titer true or false?', 'Is remedisivir a life saving drug?', ' Is remedisivir the only drug that saves lives?', 'Is there a green pass for covax vaccine?', ' Is the covax vaccine funded by the eu?', 'Do you have to get a t cell vaccine?', ' Is it possible to get t cell immunity?', 'Is there such a thing as dehydration?', ' Is there a difference between water and electrolytes?', 'Is there a pandemic in korea?', ' Is korea part of the pandemic response?', 'Is vax it and mask it the same thing?', ' Is there a difference between delta and delta strain?', 'Is the delta vaccine true or false?', ' Is the pfizer delta vaccine true or false?', 'Do you have to go to the doctor for treatment?', ' Is it normal to have a headache?', 'Is there s
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Is delta variant the fastest covid variant?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                           strings
# 549   0.985857               Is delta the fastest covid variant?
# 550   0.967243   Is delta the fastest and fittest covid variant?
# 1813  0.943949           Is the delta variant the same as covid?
# 985   0.936007                 Is deltaariant the same as covid?
# 428   0.932620        Is delta variant the same as delta strain?
# ...        ...                                               ...
# 120   0.379439           Does sputnikvaccine neutralize b.1.351?
# 1016  0.360321                     Can a person die from b1.1.7?
# 1035  0.076155                                                 "
# 1642  0.076155                                                 "
# 256   0.076155                                                 "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Does sars cov-2 affect the innate immune system?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 361   0.957534   Is sars cov-2 good for the innate immune system?
# 362   0.924931   Does sars cov-2 suppress the innate immune sy...
# 1554  0.859005  Is your immune system still active after an in...
# 1062  0.856907  Is there such a thing as an anti-vaccine movem...
# 735   0.855559            Is there a vaccine for t-cell immunity?
# ...        ...                                                ...
# 894   0.355808                Is there a vaccine in quatuquerque?
# 120   0.340448            Does sputnikvaccine neutralize b.1.351?
# 256   0.075066                                                  "
# 1035  0.075066                                                  "
# 1642  0.075066                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'What is the correlation between vaccination rate and case count?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 452   0.984806   Is there a correlation between vaccination ra...
# 451   0.980702  Is there a correlation between vaccination rat...
# 726   0.927935   Is there a difference between intubation and ...
# 1648  0.924921   Is there a correlation between vaccines and i...
# 248   0.918637  Is there such thing as low platelet after vacc...
# ...        ...                                                ...
# 1016  0.398572                      Can a person die from b1.1.7?
# 483   0.394336       Is it possible to have a b.1.617.2 mutation?
# 256   0.077582                                                  "
# 1642  0.077582                                                  "
# 1035  0.077582                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Should we still wear a mask?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 884   0.877614                  Is it illegal to not wear a mask?
# 883   0.875272              Is it legal to wear a mask in the us?
# 1595  0.871471             Is there a public rally with no masks?
# 1168  0.866169                  Is it safe to wear a double mask?
# 976   0.846828   Is there such thing as a lack of women in the...
# ...        ...                                                ...
# 529   0.257038      Is b.1.617.2 a variant of concern in ontario?
# 1138  0.257038      Is b.1.617.2 a variant of concern in ontario?
# 1642  0.078771                                                  "
# 256   0.078771                                                  "
# 1035  0.078771                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Is covid vaccine safe and how much effective is it?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                        strings
# 206   0.949362       Is the covid vaccine safe and effective?
# 1423  0.945859       Is the sinovac vaccine safe in the wild?
# 306   0.929844   Is the hcfi vaccine a true or false vaccine?
# 166   0.928932   Is the covid vaccine effective if not given?
# 548   0.927766        Is there a vaccine for covid in the us?
# ...        ...                                            ...
# 120   0.376880        Does sputnikvaccine neutralize b.1.351?
# 483   0.374657   Is it possible to have a b.1.617.2 mutation?
# 1642  0.093962                                              "
# 1035  0.093962                                              "
# 256   0.093962                                              "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Do you need to be vaccinated against covid19?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                           strings
# 455   0.981449     Do you have to be vaccinated against covid19?
# 587   0.930403       Do you have to be vaccinated against covid?
# 502   0.929487   Do you have to get vaccinated against covid-19?
# 820   0.928931       Do you have to be vaccinated against covid?
# 1243  0.928931       Do you have to be vaccinated against covid?
# ...        ...                                               ...
# 1424  0.396215                   Is 3 weeks the same as 8 weeks?
# 894   0.361327               Is there a vaccine in quatuquerque?
# 1642  0.082388                                                 "
# 1035  0.082388                                                 "
# 256   0.082388                                                 "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Does covid cause illness in kids?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 903   0.917326                         Is covid harmless in kids?
# 1543  0.873367   Is science and solidarity the key to a succes...
# 1706  0.855383                 Does covishield cause blood clots?
# 371   0.850705  Is public health and social measures effective...
# 904   0.844208         Is it true that covid is harmless in kids?
# ...        ...                                                ...
# 1138  0.335966      Is b.1.617.2 a variant of concern in ontario?
# 529   0.335966      Is b.1.617.2 a variant of concern in ontario?
# 256   0.075286                                                  "
# 1035  0.075286                                                  "
# 1642  0.075286                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Is it normal to have a fever or headache?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                       strings
# 21    0.963056              Is it normal to have a headache?
# 1808  0.948694         Is there a vaccine for delta vietnam?
# 113   0.947420         Is the moderna vaccine true or false?
# 694   0.941411            Is there a new normal after covid?
# 1249  0.933632        Is it true or false to have a vaccine?
# ...        ...                                           ...
# 483   0.397978  Is it possible to have a b.1.617.2 mutation?
# 120   0.348747       Does sputnikvaccine neutralize b.1.351?
# 1035  0.103097                                             "
# 256   0.103097                                             "
# 1642  0.103097                                             "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Is there any side effect of moderna vaccine?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 112   0.982397         Is there a side effect of moderna vaccine?
# 1405  0.938646            Is there a difference in vaccine cases?
# 724   0.936632   Is there a difference between true and false ...
# 1873  0.935787  Is there a vaccine verification system in france?
# 723   0.932721  Is there a difference between true and false e...
# ...        ...                                                ...
# 120   0.377140            Does sputnikvaccine neutralize b.1.351?
# 483   0.344372       Is it possible to have a b.1.617.2 mutation?
# 1642  0.084963                                                  "
# 1035  0.084963                                                  "
# 256   0.084963                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Are toci and remdesivir the same?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                       strings
# 33    0.951193      Is remeddesivir and toci the same thing?
# 32    0.944238        Is toci and remdesivir the same thing?
# 1744  0.922563       Is there a pandemic in the middle east?
# 301   0.920192       Is there a reason for vaccine mandates?
# 113   0.917252         Is the moderna vaccine true or false?
# ...        ...                                           ...
# 483   0.372652  Is it possible to have a b.1.617.2 mutation?
# 120   0.366282       Does sputnikvaccine neutralize b.1.351?
# 256   0.079311                                             "
# 1642  0.079311                                             "
# 1035  0.079311                                             "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Are oxford vaccine and astra zeneca same?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                           strings
# 888   0.942192   Is the oxford vaccine the same as astra zeneca?
# 1312  0.916809         Is there a vaccine for covax in tanzania?
# 1573  0.915433          Are moderna and pfizer the same vaccine?
# 887   0.902637    Is the oxford and astra zeneca the same thing?
# 1572  0.895476           Is moderna and pfizer the same vaccine?
# ...        ...                                               ...
# 373   0.359733                     Is it possible to be on b117?
# 483   0.308757      Is it possible to have a b.1.617.2 mutation?
# 1035  0.072721                                                 "
# 256   0.072721                                                 "
# 1642  0.072721                                                 "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Are cdc guidlines on masking changed?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 1833  0.971608          Is the cdc guidance on masking unchanged?
# 1834  0.949992   Does the cdc have guidance on masking unchanged?
# 859   0.898695                        Can smoking lead to cancer?
# 1553  0.886461        Do all nursing home workers get vaccinated?
# 1552  0.878639            Do nursing home workers get vaccinated?
# ...        ...                                                ...
# 894   0.349096                Is there a vaccine in quatuquerque?
# 483   0.296320       Is it possible to have a b.1.617.2 mutation?
# 1642  0.069772                                                  "
# 256   0.069772                                                  "
# 1035  0.069772                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Are delta and gamma variant different?'

tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 1823  0.932920  Is there a difference between delta and gamma ...
# 1824  0.925015   Is there a difference between delta and gamma...
# 1752  0.889550    Do beta and gamma variants have the same titer?
# 1386  0.886984             Is there a vaccine for lambda variant?
# 134   0.883590           Is delta and deltaariant the same thing?
# ...        ...                                                ...
# 483   0.315737       Is it possible to have a b.1.617.2 mutation?
# 373   0.314321                      Is it possible to be on b117?
# 1035  0.064928                                                  "
# 1642  0.064928                                                  "
# 256   0.064928                                                  "
#
# [1897 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

string = 'Can you take the covid19 vaccine if you have high blood pressure?'


tfidf_vectorizer = TfidfVectorizer(analyzer="char")

sparse_matrix = tfidf_vectorizer.fit_transform([string]+questions)
cosine = cosine_similarity(sparse_matrix[0,:],sparse_matrix[1:,:])

# %%
pd.DataFrame({'cosine':cosine[0],'strings':questions}).sort_values('cosine',ascending=False)
# Out:
#         cosine                                            strings
# 1350  0.982988  Can you take the covid19 vaccine for high bloo...
# 572   0.908436                  Is there a covid 19 in la county?
# 455   0.905067      Do you have to be vaccinated against covid19?
# 542   0.904938      Do you have to be vaccinated against the flu?
# 919   0.904546        Is the movie covid19 based on a true story?
# ...        ...                                                ...
# 717   0.428996  Is there a difference between 300 and 300 anti...
# 894   0.417294                Is there a vaccine in quatuquerque?
# 1642  0.095421                                                  "
# 256   0.095421                                                  "
# 1035  0.095421                                                  "
#
# [1897 rows x 2 columns]
